# %%
print("Airways welcome you\n")

print("Hello pilot,please give the flight details.")     
ch=int(input("What is the present height of the aeroplane in air:")) 
#ch current height
height=1200
print("the Present height of the aeroplane is "+str(ch)+".Pilot,we request you to")
if(ch<=height):
    print("safe to land .")
elif (ch>height and ch<4000):
     print("Bring down to 1200ft.")          
else:
    print("Turn around and try later.")

print("Thank you happy journy")
# Out:
# Welcome everyone to Airway
#
# Hello pilot,please give the flight details.
# What is the current height of the flight in air:675
# the Present height of the flight is 675.Pilot,we request you to
# safe to land .
# Thank you safe landing
